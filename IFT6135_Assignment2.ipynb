# %% [markdown]
# <a href="https://colab.research.google.com/github/andreeadeac22/IFT6135H20/blob/master/IFT6135_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python run_exp.py --model=RNN --optimizer=SGD --initial_lr=1.0 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3201.6700410842896	speed (wps):15774.718551483113
# step: 30	loss (sum over all examples' seen this epoch):8395.521776676178	speed (wps):16195.300925879588
# step: 50	loss (sum over all examples' seen this epoch):13424.514231681824	speed (wps):16303.060660753354
# step: 70	loss (sum over all examples' seen this epoch):18374.745721817017	speed (wps):16366.356645745116
# step: 90	loss (sum over all examples' seen this epoch):23268.043916225433	speed (wps):16394.499345642416
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
! zip -r RNN_SGD_model\=RNN_optimizer\=SGD_initial_lr\=1.0_batch_size\=128_seq_len\=35_hidden_size\=512_num_layers\=2_dp_keep_prob\=0.8_num_epochs\=20_save_best_0.zip RNN_SGD_model\=RNN_optimizer\=SGD_initial_lr\=1.0_batch_size\=128_seq_len\=35_hidden_size\=512_num_layers\=2_dp_keep_prob\=0.8_num_epochs\=20_save_best_0

# %%
! mv /content/RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=RNN --optimizer=SGD --initial_lr=1.0 --batch_size=20  --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3204.120297431946	speed (wps):7335.980538021047
# step: 142	loss (sum over all examples' seen this epoch):35860.75391292572	speed (wps):7838.265743658307
# step: 274	loss (sum over all examples' seen this epoch):67335.68312883377	speed (wps):7867.824477182468
# step: 406	loss (sum over all examples' seen this epoch):98280.10684490204	speed (wps):7863.092547517777
# step: 538	loss (sum over all examples' seen this epoch):128819.79669809341	speed (wps):7858.540975702279
# ...

# %%
! zip -r RNN_SGD_model\=RNN_optimizer\=SGD_initial_lr\=1.0_batch_size\=20_seq_len\=35_hidden_size\=512_num_layers\=2_dp_keep_prob\=0.8_num_epochs\=20_save_best_0.zip RNN_SGD_model\=RNN_optimizer\=SGD_initial_lr\=1.0_batch_size\=20_seq_len\=35_hidden_size\=512_num_layers\=2_dp_keep_prob\=0.8_num_epochs\=20_save_best_0
# Out:
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/ (stored 0%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/learning_curves.npy (deflated 32%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/log.txt (deflated 70%)

# %%
! mv /content/RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=RNN --optimizer=SGD --initial_lr=10.0 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):4285.695519447327	speed (wps):15683.618419739743
# step: 30	loss (sum over all examples' seen this epoch):11776.49136543274	speed (wps):16158.635777756812
# step: 50	loss (sum over all examples' seen this epoch):20741.40643119812	speed (wps):16288.051758198158
# step: 70	loss (sum over all examples' seen this epoch):30058.861241340637	speed (wps):16334.914701177193
# step: 90	loss (sum over all examples' seen this epoch):39567.665758132935	speed (wps):16358.88377353699
# ...

# %%
! zip -r RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/learning_curves.npy
# Out:
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)

# %%
! mv /content/RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=RNN --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):2967.732560634613	speed (wps):15582.504612473449
# step: 30	loss (sum over all examples' seen this epoch):7720.339884757996	speed (wps):15967.877768618066
# step: 50	loss (sum over all examples' seen this epoch):12314.30068731308	speed (wps):16038.858768959077
# step: 70	loss (sum over all examples' seen this epoch):16749.85868215561	speed (wps):16070.233636309738
# step: 90	loss (sum over all examples' seen this epoch):21055.006182193756	speed (wps):16081.695906201752
# ...

# %%
! zip -r RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0

# %%
! mv /content/RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=RNN --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3512.196307182312	speed (wps):23498.286771107385
# step: 30	loss (sum over all examples' seen this epoch):9078.720707893372	speed (wps):26394.213908132966
# step: 50	loss (sum over all examples' seen this epoch):14058.553342819214	speed (wps):27209.0144913126
# step: 70	loss (sum over all examples' seen this epoch):18836.762804985046	speed (wps):27533.805926576653
# step: 90	loss (sum over all examples' seen this epoch):23548.410229682922	speed (wps):27562.521990947957
# ...

# %%
! zip -r RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0.zip RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Out:
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/ (stored 0%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/log.txt (deflated 70%)

# %%
! mv /content/RNN_ADAM_model\=RNN_optimizer\=ADAM_initial_lr\=0.0001_batch_size\=128_seq_len\=35_hidden_size\=512_num_layers\=2_dp_keep_prob\=0.8_num_epochs\=20_save_best_0.zip /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3348.0102229118347	speed (wps):20547.49647568128
# step: 30	loss (sum over all examples' seen this epoch):8407.063646316528	speed (wps):21557.75655270673
# step: 50	loss (sum over all examples' seen this epoch):13102.741429805756	speed (wps):21445.736597815776
# step: 70	loss (sum over all examples' seen this epoch):17660.905768871307	speed (wps):21642.595246739034
# step: 90	loss (sum over all examples' seen this epoch):22101.595923900604	speed (wps):21719.470962319276
# ...

# %%
! zip -r GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0.zip GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Out:
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/ (stored 0%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/best_params.pt (deflated 7%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/log.txt (deflated 71%)

# %%
! mv /content/GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0.zip  /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=GRU --optimizer=SGD  --initial_lr=10.0  --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3494.05305147171	speed (wps):20919.528942628887
# step: 30	loss (sum over all examples' seen this epoch):8950.311744213104	speed (wps):21399.335679145966
# step: 50	loss (sum over all examples' seen this epoch):14138.612351417542	speed (wps):21718.9624853295
# step: 70	loss (sum over all examples' seen this epoch):19119.5174407959	speed (wps):21876.791939595503
# step: 90	loss (sum over all examples' seen this epoch):24003.65370988846	speed (wps):21911.652320642665
# ...

# %%
! zip -r GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0.zip GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Out:
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/ (stored 0%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/log.txt (deflated 70%)

# %%
! mv /content/GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0.zip /content/gdrive/My\ Drive/ift6135/Assignment2/

# %%
! python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=20 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3247.0320773124695	speed (wps):4713.703980797315
# step: 142	loss (sum over all examples' seen this epoch):33373.279740810394	speed (wps):6253.612274690756
# step: 274	loss (sum over all examples' seen this epoch):62039.66048002243	speed (wps):6318.481309788388
# step: 406	loss (sum over all examples' seen this epoch):89646.09135866165	speed (wps):6364.621196617837
# step: 538	loss (sum over all examples' seen this epoch):116894.94195699692	speed (wps):6401.181928742882
# ...

# %%
! python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=256 --num_layers=2 --dp_keep_prob=0.2  --num_epochs=20 --save_best

# %%
! python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=2048 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best

# %%
! python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=4 --dp_keep_prob=0.5  --num_epochs=20 --save_best

# %%
! python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512  --num_layers=6 --dp_keep_prob=0.9 --num_epochs=20 --save_best

# %%
! python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512  --num_layers=2 --dp_keep_prob=0.9 --num_epochs=20 --save_best

# %%
! python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=2048 --num_layers=2 --dp_keep_prob=0.6 --num_epochs=20 --save_best

# %%
! python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=1024 --num_layers=6 --dp_keep_prob=0.9 --num_epochs=20 --save_best
